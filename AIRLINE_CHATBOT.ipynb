# %%
def read_dataset():
    f=open("Airport_DataSet","r");
    d_full_name={}
    d_abbr={}
    for i in f:
        s=i.split("   ")
        d_full_name[s[0].lower()]=s[1].lower()
        s1=s[1].split(" ")
        s2=s1[len(s1)-1].replace('(','').replace(')','')
       # print s2
        d_abbr[s2.lower()]=s[0].lower()
        
    return d_full_name,d_abbr
d_full_name,d_abbr=read_dataset()

# %%
    class NERNode:  
        def __init__(self): 
            self.children = [None]*26
  
        # isEndOfWord is True if node represent the end of the word 
            self.isEndOfWord = False
      



    class NER: 
      
    # Trie data structure class 
        def __init__(self): 
            self.root = self.getNode() 
  
        def getNode(self): 
      
            # Returns new trie node (initialized to NULLs) 
            return NERNode() 
  
        def _charToIndex(self,ch): 
          
        # private helper function 
        # Converts key current character into index 
        # use only 'a' through 'z' and lower case 
          
            return ord(ch)-ord('a') 
  
  
        def insert(self,key): 
          
        # If not present, inserts key into trie 
        # If the key is prefix of trie node,  
        # just marks leaf node 
            pCrawl = self.root 
            length = len(key) 
            for level in range(length): 
                index = self._charToIndex(key[level]) 
  
            # if current character is not present 
                if not pCrawl.children[index]: 
                    pCrawl.children[index] = self.getNode() 
                pCrawl = pCrawl.children[index] 
  
        # mark last node as leaf 
            pCrawl.isEndOfWord = True
  
        def search(self, key): 
          
        # Search key in the trie 
        # Returns true if key presents  
        # in trie, else false 
            pCrawl = self.root 
            length = len(key) 
            for level in range(length): 
                index = self._charToIndex(key[level]) 
                if not pCrawl.children[index]: 
                    return False
                pCrawl = pCrawl.children[index] 
  
            return pCrawl != None and pCrawl.isEndOfWord 
  
# driver function 
    def verify_city_name(): 
         
        output = [False,True] 
  
        t = NER() 
  
        for key in d_full_name: 
            t.insert(key)
        for key in d_abbr:
            if(key.isalpha()):
                t.insert(key)
        print(output[t.search("carnicobar")]) 
        return t
       

    t=verify_city_name()
# Out:
# True

# %%
import string

import random

GREETING_KEYWORDS = ("hello", "hi", "greetings", "sup", "what's up","hey")

GREETING_RESPONSES = ["HI,I am your helper for the day", "Hey", "HI! I am here to help","HI! I am Harry the chatbot.Ask me anything and I will try to help you"]

def check_for_greeting(sentence):
    """If any of the words in the user's input was a greeting, return a greeting response"""
    for word in sentence.split():
        if word.lower() in GREETING_KEYWORDS:
            return random.choice(GREETING_RESPONSES)
    return random.choice(GREETING_RESPONSES)

# %%
import re
from nltk import word_tokenize
from autocorrect import spell
import string
import random

def extract_src_dest(query):
    
    #print check_for_greeting(query)
    SOURCE_NOT_FOUND_RESPONSES = ['I can look into your options for you. Where would you like to depart from?',
                                  'Please provide Source Location',
                                  'Which city will you be departing from?',
                                  'Sure, where would you be flying out of?'
                                 ]
    DESTINATION_NOT_FOUND_RESPONSES = ['Would surely help you only if you can provide me with the destination location',
                                       'Please enter Destination Location',
                                       'What a beautiful place to be in <3 . Would you please help me with the destination location',
                                       'Sure, where would you be flying out to?'
                                      ]
    output = [False,True] 
    query=query.lower()
    tokenize_query=word_tokenize(query)
    from_index=-1
    to_index=-1
    place1=-1
    place2=-1
    
    t=NER()
    for key in d_full_name: 
        t.insert(key)
    for key in d_abbr:
        if(key.isalpha()):
            t.insert(key)
    i=0
    flag=0
    for word in tokenize_query:
        
        
        if(word in ['from','start','starting','source','fro']):
            from_index=i
        if(word in ['to','destination','end','in']):
            to_index=i
        if word.isalpha() and output[t.search(word)] and flag == 0:
            place1=i
            flag=1
        elif word.isalpha() and output[t.search(word)] and flag == 1:
            place2=i
        i=i+1;
    
    if(from_index<to_index and to_index!=-1 and from_index!=-1):
        
        
        if(place1==-1):
            return (False,False,random.choice(SOURCE_NOT_FOUND_RESPONSES))
            
        if(place2==-1):
            return (False,False,random.choice(DESTINATION_NOT_FOUND_RESPONSES))
            
        
        if(place1!=-1):
            print "Source = " + tokenize_query[place1]
        if(place2!=-1):
            print "Destination = " + tokenize_query[place2] 
            
        return (True,tokenize_query[place1],tokenize_query[place2])
        
    elif(from_index>to_index and to_index!=-1 and from_index!=-1):
        if(place2==-1):
            return (False,False,random.choice(SOURCE_NOT_FOUND_RESPONSES))
        if(place1==-1):
            return (False,False,random.choice(DESTINATION_NOT_FOUND_RESPONSES))
            
        if(place2!=-1):
            print "Source = " + tokenize_query[place2]
        if(place1!=1):
            print "Destination = " + tokenize_query[place1]
            
        return (True,tokenize_query[place2],tokenize_query[place1])
    elif(from_index==-1 and to_index!=-1):
        if(place1!=-1 and place2!=-1):
            if((to_index-place1)>0):
                temp=to_index-place1
                if((to_index-place2)>0 and temp<(to_index-place2)):
                    print "Source = " + tokenize_query[place2]
                    print "Destination = " + tokenize_query[place1]
                    return (True,tokenize_query[place2],tokenize_query[place1])
                else:
                    print "Source = " + tokenize_query[place1]
                    print "Destination = " + tokenize_query[place2]
                    return (True,tokenize_query[place1],tokenize_query[place2])
        else:
            if(place1!=-1):
                return (False,False,random.choice(SOURCE_NOT_FOUND_RESPONSES))
    elif(from_index!=-1 and to_index==-1):
        print "Source = " + tokenize_query[place1]
        print "Destination = " + tokenize_query[place2]
        return (True,tokenize_query[place1],tokenize_query[place2])
        
            
#     print tokenize_query[place1],tokenize_query[place2]        
    if(place1 == -1 and place2 == -1):
        return (False,False,"Please enter as source:location and destination:location")
    else:
        return (True,tokenize_query[place1],tokenize_query[place2]) 
    
    
            
            

def spell_check(query):
    s=""
    for i in query.split(" "):
        s+=spell(i)+" "
    return s.lower()

query="Please book me a flight ticket to Delhi"

extract_src_dest(spell_check(query))
# Out:
# (False,
#  False,
#  'I can look into your options for you. Where would you like to depart from?')

# %%
import nltk
import string
import random
import datefinder
import datetime
from pymongo import MongoClient

RESULTS_NOT_FOUND_RESPONSES = ['I checked a few options for you, and unfortunately, we do not currently have any trips that meet this criteria.  Would you like to book an alternate travel option?',
                               'I\'m sorry, I do not have that information',
                               'No Trips Found :('
                              ]

DATE_NOT_PRESENT_RESPONSED = ['Great!! Sounds like a plan to me,When are you planning to leave?',
                              'Do you have a date in mind?',
                              'Can you please tell me when would you want to leave?',
                              'Help me with the date of departure please.',
                              'I can look into your options for you. When would you like to depart?',
                              'I like the sound of that. What are the departure date and time for this one?'
                             ]

def check_for_dates(sentence):
    
    tokenize_sentence=word_tokenize(sentence)
    now = datetime.datetime.now()
    matches = datefinder.find_dates(sentence)

    for match in matches:
        print match
        return True,match
        
    for word in tokenize_sentence:
        if(word.lower() == 'today'):
            tdy = (str(now).split(" ")[0]+" "+"00:00:00")
            print tdy
            return True,tdy
        if(word.lower()=='tomorrow'):
            tmrw = (str(datetime.date.today() + datetime.timedelta(days=1))+" "+"00:00:00")
            print tmrw
            return True,tmrw
        
    return False,random.choice(DATE_NOT_PRESENT_RESPONSED)
        
print check_for_dates('I would like to travel fro DEHRADUN to Hyderabad ')
# Out:
# (False, 'Can you please tell me when would you want to leave?')

# %%
import sys
from pymongo import MongoClient
def query_results(source,destination,date,budget):
    uri='mongodb://edgecomputing:edgecomputing19@ds111461.mlab.com:11461/iasproject'

    client = MongoClient(uri,connectTimeoutMS=3000000)

    db = client.get_database()

    flights=db.get_collection("flights")


    results = flights.find({"source":source,"destination":destination})
    print 'SOURCE\t\tDESTINATION\t\tTIME\tAIRLINE_CODE\tFLIGHT_NUMBER\tPRICE'
    for doc in results:
        c=int(doc['Price'],10)
        if(c<=budget):
            print '------------------------------------------------------------------------------------------------'
            print " "+d_abbr[doc['source'].lower()].upper()+"\t\t   "+d_abbr[doc['destination'].lower()].upper()+"\t          "+doc['time']+"\t    "+doc['Airline_Code']+"\t             "+doc['FLIGHT_NUMBER']+"\t"+doc['Price']

# %%
extract_src_dest(spell_check(query))
source='mumbai'
destination='delhi'
if(source in d_full_name):
    src=d_full_name[source].split(" ")
    src=src[len(src)-1].replace("(","")
    src=src.replace(")","")
if(destination in d_full_name):
    dest=d_full_name[destination].split(" ")
    dest=dest[len(dest)-1].replace("(","")
    dest=dest.replace(")","")

print src,dest
# Out:
# bom del

# %%
s1,date=check_for_dates('I would like to travel fro DEHRADUN to Hyderabad today ')
print date.split(" ")[0]
# Out:
# 2018-11-16 00:00:00
# 2018-11-16

# %%
query_results(src.upper(),dest.upper(),"1140",1600)
# Out:
# SOURCE		DESTINATION		TIME	AIRLINE_CODE	FLIGHT_NUMBER	PRICE
# ------------------------------------------------------------------------------------------------
#  MUMBAI		   DELHI	          10	    SG	             985	1229
# ------------------------------------------------------------------------------------------------
#  MUMBAI		   DELHI	          40	    G8	             544	1460
# ------------------------------------------------------------------------------------------------
#  MUMBAI		   DELHI	          55	    UK	             923	1385
# ------------------------------------------------------------------------------------------------
#  MUMBAI		   DELHI	          435	    9W	             313	1251
# ------------------------------------------------------------------------------------------------
#  MUMBAI		   DELHI	          805	    UK	             975	1522
# ------------------------------------------------------------------------------------------------
# ...

# %%
def getBudget(query):
    tokenize_sentence=word_tokenize(query)
    for i in tokenize_sentence:
        if(i.isdigit()):
            return (True,i)
    return (False,False)
getBudget("My budget is 1500")
# Out:
# (True, '1500')

# %%
def ChatBot():
    s=raw_input()
    s1=check_for_greeting(spell_check(s))
    print "BOT>>"+s1
    s2,src,dest=extract_src_dest(spell_check(s))
    s3,date=check_for_dates(spell_check(s))
    i=1
    if(s2==False):
        print "BOT>>"+"How may I help you"
        query=raw_input()
        s2,src,dest=extract_src_dest(query)
    while(s2==False and i<=3):
        print "BOT>>"+dest
        s2,src,dest=extract_src_dest(spell_check(raw_input()))
        i=i+1
    i=1
    if(s2==False):
        print "BOT>>"+"SORRY I AM NOT ABLE TO ASSIST YOU :(\nPlease Try Again Later"
        return
    
    while(s3==False and i<=3):
        print "BOT>>"+date
        s3,date=check_for_dates(spell_check(raw_input()))
        i=i+1
    if(s3==False):
        print "BOT>>"+"SORRY I AM NOT ABLE TO ASSIST YOU :(\nPlease Try Again Later"
        return
    print "BOT>>"+"Please enter the budget if Any"
    s4,budget=getBudget(spell_check(raw_input()))
    if(s4==False): 
        budget="10000"
        
    if(src in d_full_name):
        src=d_full_name[source].split(" ")
        src=src[len(src)-1].replace("(","")
        src=src.replace(")","")
        src=src.upper()
    if(dest in d_full_name):
        dest=d_full_name[destination].split(" ")
        dest=dest[len(dest)-1].replace("(","")
        dest=dest.replace(")","")
        dest=dest.upper()
        
    print "RESULTS:"    
    query_results(src,dest,date,int(budget,10)) 
    
        
        

ChatBot()
# Out:
# Hi
# BOT>>HI! I am Harry the chatbot.Ask me anything and I will try to help you
# BOT>>How may I help you
# Please book a flight from Mumbai to Delhi
# Source = mumbai
# Destination = delhi
# BOT>>Do you have a date in mind?
# I want to book for tomorrow
# 2018-11-17 00:00:00
# BOT>>Please enter the budget if Any
# My budget for the trip is around 1500 Rs
# RESULTS:
# SOURCE		DESTINATION		TIME	AIRLINE_CODE	FLIGHT_NUMBER	PRICE
# ------------------------------------------------------------------------------------------------
#  MUMBAI		   DELHI	          10	    SG	             985	1229
# ------------------------------------------------------------------------------------------------
#  MUMBAI		   DELHI	          40	    G8	             544	1460
# ------------------------------------------------------------------------------------------------
#  MUMBAI		   DELHI	          55	    UK	             923	1385
# ...
